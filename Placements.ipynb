# %% [markdown]
# <a href="https://colab.research.google.com/github/mohansaidinesh/Machine-Learning/blob/main/Placements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=pd.read_csv("/content/students_placement_data-1.csv")

# %%
data.head()
# Out:
#    Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0        1      M       A            87.3                      65.3
# 1        2      F       A            89.0                      92.4
# 2        3      F       A            67.0                      40.2
# 3        4      M       A            71.0                      70.4
# 4        5      M       A            44.0                      65.5
#
#    B.Tech_percentage  Backlogs registered_for_ Placement_Training  \
# 0              40.00        18                                 NO
# 1              21.20         0                                yes
# 2                NaN        13                                yes
# 3              36.47        17                                yes
# 4              42.52        17                                yes
#
#   placement status
# 0       Not placed
# 1           Placed
# 2       Not placed
# 3       Not placed
# 4       Not placed

# %%
data.shape
# Out:
# (117, 9)

# %%
data.isnull().sum()
# Out:
# Roll No                               0
# Gender                                0
# Section                               0
# SSC Percentage                        1
# inter_Diploma_percentage              0
# B.Tech_percentage                     1
# Backlogs                              0
# registered_for_ Placement_Training    1
# placement status                      0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 9 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Roll No                             117 non-null    int64
#  1   Gender                              117 non-null    object
#  2   Section                             117 non-null    object
#  3   SSC Percentage                      116 non-null    float64
#  4   inter_Diploma_percentage            117 non-null    float64
#  5   B.Tech_percentage                   116 non-null    float64
#  6   Backlogs                            117 non-null    int64
#  7   registered_for_ Placement_Training  116 non-null    object
#  8   placement status                    117 non-null    object
# dtypes: float64(3), int64(2), object(4)
# memory usage: 8.4+ KB

# %%
data['placement status'].unique()
# Out:
# array(['Not placed', 'Placed'], dtype=object)

# %%
independent=data.iloc[:,[0,1,2,3,4,5,6,7]]                                                      
independent
# Out:
#      Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0          1      M       A            87.3                     65.30
# 1          2      F       A            89.0                     92.40
# 2          3      F       A            67.0                     40.20
# 3          4      M       A            71.0                     70.40
# 4          5      M       A            44.0                     65.50
# ..       ...    ...     ...             ...                       ...
# 112      113      M       B            81.1                     78.60
# 113      114      M       B            81.3                     85.12
# 114      115      M       B            83.5                     89.90
# 115      116      M       B            85.5                     90.63
# 116      117      M       B            80.0                     83.33
#
#      B.Tech_percentage  Backlogs registered_for_ Placement_Training
# ...

# %%
dependent=data.iloc[:,-1]
dependent
# Out:
# 0      Not placed
# 1          Placed
# 2      Not placed
# 3      Not placed
# 4      Not placed
#           ...
# 112    Not placed
# 113    Not placed
# 114    Not placed
# 115    Not placed
# 116    Not placed
# Name: placement status, Length: 117, dtype: object

# %%
data.describe()
# Out:
#           Roll No  SSC Percentage  inter_Diploma_percentage  \
# count  117.000000      116.000000                117.000000
# mean    59.000000       80.153362                 80.535299
# std     33.919021        9.462320                 11.818567
# min      1.000000       44.000000                 40.200000
# 25%     30.000000       75.875000                 73.400000
# 50%     59.000000       82.745000                 83.600000
# 75%     88.000000       87.025000                 90.000000
# max    117.000000       93.660000                 96.900000
#
#        B.Tech_percentage    Backlogs
# count         116.000000  117.000000
# mean           62.662672    4.111111
# std            12.591167    6.335148
# min            21.200000    0.000000
# 25%            54.175000    0.000000
# 50%            63.885000    0.000000
# 75%            72.570000    7.000000
# max            88.100000   25.000000

# %%
import seaborn as sns

# %%
sns.scatterplot(x='Section',y='Backlogs',data=data)
# Out:
# <Axes: xlabel='Section', ylabel='Backlogs'>

# %%
sns.barplot(x='Gender',y='B.Tech_percentage',data=data,hue='Section')
# Out:
# <Axes: xlabel='Gender', ylabel='B.Tech_percentage'>

# %%
sns.violinplot(x='Gender',y='B.Tech_percentage',data=data,hue='Section')
# Out:
# <Axes: xlabel='Gender', ylabel='B.Tech_percentage'>

# %%
sns.boxplot(x='Backlogs',y='placement status',data=data,hue='Gender')
# Out:
# <Axes: xlabel='Backlogs', ylabel='placement status'>

# %%
sns.lineplot(x=data["B.Tech_percentage"],y=data['placement status'])
# Out:
# <Axes: xlabel='B.Tech_percentage', ylabel='placement status'>

# %%
data.shape
# Out:
# (117, 9)

# %%
data.head()
# Out:
#    Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0        1      M       A            87.3                      65.3
# 1        2      F       A            89.0                      92.4
# 2        3      F       A            67.0                      40.2
# 3        4      M       A            71.0                      70.4
# 4        5      M       A            44.0                      65.5
#
#    B.Tech_percentage  Backlogs registered_for_ Placement_Training  \
# 0              40.00        18                                 NO
# 1              21.20         0                                yes
# 2                NaN        13                                yes
# 3              36.47        17                                yes
# 4              42.52        17                                yes
#
#   placement status
# 0       Not placed
# 1           Placed
# 2       Not placed
# 3       Not placed
# 4       Not placed

# %%
from sklearn.preprocessing import LabelEncoder
encode_label = LabelEncoder()
data.Gender = encode_label.fit_transform(data.Gender)
Gender = pd.DataFrame(zip(encode_label.classes_,encode_label.transform(encode_label.classes_)),columns=['Original','Encoded'])
Gender = Gender.set_index('Original')
Gender
# Out:
#           Encoded
# Original
# F               0
# M               1

# %%
data.head()
# Out:
#    Roll No  Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0        1       1       A            87.3                      65.3
# 1        2       0       A            89.0                      92.4
# 2        3       0       A            67.0                      40.2
# 3        4       1       A            71.0                      70.4
# 4        5       1       A            44.0                      65.5
#
#    B.Tech_percentage  Backlogs registered_for_ Placement_Training  \
# 0              40.00        18                                 NO
# 1              21.20         0                                yes
# 2                NaN        13                                yes
# 3              36.47        17                                yes
# 4              42.52        17                                yes
#
#   placement status
# 0       Not placed
# 1           Placed
# 2       Not placed
# 3       Not placed
# 4       Not placed

# %%
data.Section = encode_label.fit_transform(data.Section)
Section = pd.DataFrame(zip(encode_label.classes_,encode_label.transform(encode_label.classes_)),columns=['Original','Encoded'])
Section = Section.set_index('Original')
Section
# Out:
#           Encoded
# Original
# A               0
# B               1

# %%
data.head()
# Out:
#    Roll No  Gender  Section  SSC Percentage  inter_Diploma_percentage  \
# 0        1       1        0            87.3                      65.3
# 1        2       0        0            89.0                      92.4
# 2        3       0        0            67.0                      40.2
# 3        4       1        0            71.0                      70.4
# 4        5       1        0            44.0                      65.5
#
#    B.Tech_percentage  Backlogs registered_for_ Placement_Training  \
# 0              40.00        18                                 NO
# 1              21.20         0                                yes
# 2                NaN        13                                yes
# 3              36.47        17                                yes
# 4              42.52        17                                yes
#
#   placement status
# 0       Not placed
# 1           Placed
# 2       Not placed
# 3       Not placed
# 4       Not placed

# %%
data.rename(columns={'registered_for_ Placement_Training':'Registered'},inplace=True)

# %%
data.head()
# Out:
#    Roll No  Gender  Section  SSC Percentage  inter_Diploma_percentage  \
# 0        1       1        0            87.3                      65.3
# 1        2       0        0            89.0                      92.4
# 2        3       0        0            67.0                      40.2
# 3        4       1        0            71.0                      70.4
# 4        5       1        0            44.0                      65.5
#
#    B.Tech_percentage  Backlogs Registered placement status
# 0              40.00        18         NO       Not placed
# 1              21.20         0        yes           Placed
# 2                NaN        13        yes       Not placed
# 3              36.47        17        yes       Not placed
# 4              42.52        17        yes       Not placed

# %%
data.Registered = encode_label.fit_transform(data.Section)
Registered = pd.DataFrame(zip(encode_label.classes_,encode_label.transform(encode_label.classes_)),columns=['Original','Encoded'])
Registered = Registered.set_index('Original')
Registered
# Out:
#           Encoded
# Original
# 0               0
# 1               1

# %%
data.head()
# Out:
#    Roll No  Gender  Section  SSC Percentage  inter_Diploma_percentage  \
# 0        1       1        0            87.3                      65.3
# 1        2       0        0            89.0                      92.4
# 2        3       0        0            67.0                      40.2
# 3        4       1        0            71.0                      70.4
# 4        5       1        0            44.0                      65.5
#
#    B.Tech_percentage  Backlogs  Registered placement status
# 0              40.00        18           0       Not placed
# 1              21.20         0           0           Placed
# 2                NaN        13           0       Not placed
# 3              36.47        17           0       Not placed
# 4              42.52        17           0       Not placed

# %%
data.rename(columns={'SSC Percentage':'SSC','inter_Diploma_percentage':'Inter','B.Tech_percentage':'BTech','placement status':'Placed'},inplace=True)

# %%
data.head()
# Out:
#    Roll No  Gender  Section   SSC  Inter  BTech  Backlogs  Registered  \
# 0        1       1        0  87.3   65.3  40.00        18           0
# 1        2       0        0  89.0   92.4  21.20         0           0
# 2        3       0        0  67.0   40.2    NaN        13           0
# 3        4       1        0  71.0   70.4  36.47        17           0
# 4        5       1        0  44.0   65.5  42.52        17           0
#
#        Placed
# 0  Not placed
# 1      Placed
# 2  Not placed
# 3  Not placed
# 4  Not placed

# %%
data.Placed = encode_label.fit_transform(data.Section)
Placed = pd.DataFrame(zip(encode_label.classes_,encode_label.transform(encode_label.classes_)),columns=['Original','Encoded'])
Placed= Placed.set_index('Original')
Placed
# Out:
#           Encoded
# Original
# 0               0
# 1               1

# %%
data.head()
# Out:
#    Roll No  Gender  Section   SSC  Inter  BTech  Backlogs  Registered  Placed
# 0        1       1        0  87.3   65.3  40.00        18           0       0
# 1        2       0        0  89.0   92.4  21.20         0           0       0
# 2        3       0        0  67.0   40.2    NaN        13           0       0
# 3        4       1        0  71.0   70.4  36.47        17           0       0
# 4        5       1        0  44.0   65.5  42.52        17           0       0

# %%
data.shape
# Out:
# (117, 9)

# %%
data.describe()
# Out:
#           Roll No      Gender     Section         SSC       Inter       BTech  \
# count  117.000000  117.000000  117.000000  116.000000  117.000000  116.000000
# mean    59.000000    0.581197    0.487179   80.153362   80.535299   62.662672
# std     33.919021    0.495485    0.501985    9.462320   11.818567   12.591167
# min      1.000000    0.000000    0.000000   44.000000   40.200000   21.200000
# 25%     30.000000    0.000000    0.000000   75.875000   73.400000   54.175000
# 50%     59.000000    1.000000    0.000000   82.745000   83.600000   63.885000
# 75%     88.000000    1.000000    1.000000   87.025000   90.000000   72.570000
# max    117.000000    1.000000    1.000000   93.660000   96.900000   88.100000
#
#          Backlogs  Registered      Placed
# count  117.000000  117.000000  117.000000
# mean     4.111111    0.487179    0.487179
# std      6.335148    0.501985    0.501985
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
data.dropna(inplace=True)

# %%
X=data.iloc[:,1:-1]
X
# Out:
#      Gender  Section   SSC  Inter  BTech  Backlogs  Registered
# 0         1        0  87.3  65.30  40.00        18           0
# 1         0        0  89.0  92.40  21.20         0           0
# 3         1        0  71.0  70.40  36.47        17           0
# 4         1        0  44.0  65.50  42.52        17           0
# 6         1        0  71.0  56.50  33.77        20           0
# ..      ...      ...   ...    ...    ...       ...         ...
# 112       1        1  81.1  78.60  35.84        16           1
# 113       1        1  81.3  85.12  68.50         0           1
# 114       1        1  83.5  89.90  76.30         0           1
# 115       1        1  85.5  90.63  74.50         0           1
# 116       1        1  80.0  83.33  65.53         0           1
#
# [115 rows x 7 columns]

# %%
y=data.iloc[:,-1]
y
# Out:
# 0      0
# 1      0
# 3      0
# 4      0
# 6      0
#       ..
# 112    1
# 113    1
# 114    1
# 115    1
# 116    1
# Name: Placed, Length: 115, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 115 entries, 0 to 116
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Roll No     115 non-null    int64
#  1   Gender      115 non-null    int64
#  2   Section     115 non-null    int64
#  3   SSC         115 non-null    float64
#  4   Inter       115 non-null    float64
#  5   BTech       115 non-null    float64
#  6   Backlogs    115 non-null    int64
#  7   Registered  115 non-null    int64
#  8   Placed      115 non-null    int64
# dtypes: float64(3), int64(6)
# memory usage: 9.0 KB

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,y,test_size=0.1,random_state=42)

# %%
X_train.shape
# Out:
# (103, 7)

# %%
X_test.shape
# Out:
# (12, 7)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model=DecisionTreeClassifier()
model.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.score(X_train,Y_train)
# Out:
# 1.0

# %%
Y_pred=model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
confusion_matrix(Y_test,Y_pred)
# Out:
# array([[7, 0],
#        [0, 5]])

# %%
print(classification_report(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         7
#            1       1.00      1.00      1.00         5
#
#     accuracy                           1.00        12
#    macro avg       1.00      1.00      1.00        12
# weighted avg       1.00      1.00      1.00        12

# %%
input=[[0,1,76.83,80.4,72.73,0,1]]
ans=model.predict(input)
print(ans)
# Out:
# [1]
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
