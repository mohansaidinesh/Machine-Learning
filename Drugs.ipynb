# %% [markdown]
# <a href="https://colab.research.google.com/github/mohansaidinesh/Machine-Learning/blob/main/Drugs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("/content/datafile.csv")
data.head()
# Out:
#                       State/UT   Area  Ever tobacco users (%)  \
# 0                        India  Total                    18.1
# 1                        India  Urban                    13.5
# 2                        India  Rural                    19.5
# 3  Andaman and Nicobar Islands  Total                    21.5
# 4  Andaman and Nicobar Islands  Urban                    13.3
#
#    Current tobacco users (%)  Ever tobacco smokers (%)  \
# 0                        8.5                      11.0
# 1                        5.5                       8.1
# 2                        9.4                      11.8
# 3                        4.4                       8.8
# 4                        3.4                       6.5
#
#    Current tobacco smokers (%)  Ever cigarette users (%)  \
# 0                          7.3                       4.6
# 1                          4.5                       4.1
# 2                          8.1                       4.7
# ...

# %%
data.shape
# Out:
# (107, 59)

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 59 columns):
#  #   Column                                                                                                                                 Non-Null Count  Dtype
# ---  ------                                                                                                                                 --------------  -----
#  0   State/UT                                                                                                                               107 non-null    object
#  1   Area                                                                                                                                   107 non-null    object
#  2   Ever tobacco users (%)                                                                                                                 107 non-null    float64
# ...

# %%
data.plot(kind='scatter',x='Ever tobacco users (%)',y='Current tobacco users (%)')
plt.show()

# %%
sns.barplot(x ='Area', y ='Students who thought it is difficult to quit once someone starts smoking tobacco (%)', data = data)
# Out:
# <Axes: xlabel='Area', ylabel='Students who thought it is difficult to quit once someone starts smoking tobacco (%)'>
